# %% [markdown]
# # Text Splitting Technique - Recursive Character

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
pdf_loader = PyPDFLoader('attention.pdf')

# %%
pdf_docs = pdf_loader.load()

# %%
pdf_docs
